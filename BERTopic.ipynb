# %%
# !pip install requests
# !pip install Image
from  bertopic import BERTopic
# Out:
# Requirement already satisfied: requests in /home/salwynm/miniconda3/envs/bertopic/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/salwynm/miniconda3/envs/bertopic/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/salwynm/.local/lib/python3.10/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/salwynm/miniconda3/envs/bertopic/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/salwynm/miniconda3/envs/bertopic/lib/python3.10/site-packages (from requests) (1.26.12)
# Collecting Image
#   Downloading image-1.5.33.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pillow
#   Downloading Pillow-9.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 524.5 kB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting django
#   Downloading Django-4.1.1-py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six in /home/salwynm/miniconda3/envs/bertopic/lib/python3.10/site-packages (from Image) (1.16.0)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: asgiref<4,>=3.5.2 in /home/salwynm/.local/lib/python3.10/site-packages (from django->Image) (3.5.2)
# Building wheels for collected packages: Image
#   Building wheel for Image (setup.py) ... done
#   Created wheel for Image: filename=image-1.5.33-py2.py3-none-any.whl size=19496 sha256=04937b22c6b4aaee280ef8f80c1f3abf263db9cac438a7f1b6cdf899d108bc4f
#   Stored in directory: /home/salwynm/.cache/pip/wheels/70/0c/a4/7cfa53a5c6225c2db2bfec08e782b43d0f25fdae2e995b69be
# Successfully built Image
# Installing collected packages: sqlparse, pillow, django, Image
# Successfully installed Image-1.5.33 django-4.1.1 pillow-9.2.0 sqlparse-0.4.2

# %%
from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# Batches: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 589/589 [14:16<00:00,  1.45s/it]
# 2022-09-21 23:38:23,639 - BERTopic - Transformed documents to Embeddings
# 2022-09-21 23:38:45,181 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2022-09-21 23:40:18,539 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                           Name
# 0     -1   6892                -1_to_of_the_is
# 1      0   1827           0_game_team_games_he
# 2      1    573  1_key_clipper_chip_encryption
# 3      2    525           2_ites_cheek_yep_huh
# 4      3    469     3_israel_israeli_jews_arab

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('game', 0.010288398670360875),
#  ('team', 0.008973762355035832),
#  ('games', 0.007150886802667642),
#  ('he', 0.0069618570350732725),
#  ('players', 0.006299411238230152),
#  ('season', 0.006218533806233523),
#  ('hockey', 0.006095860498324307),
#  ('play', 0.005751856534915486),
#  ('25', 0.005613706635255349),
#  ('year', 0.00558172157654)]

# %%
topic_model.topics_[:10]
# Out:
# [0, 8, 57, -1, 91, -1, 51, 0, 0, -1]

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="4a05adc7-92ab-4185-8441-a5c893244375" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a05adc7-92ab-4185-8441-a5c893244375")) {                    Plotly.newPlot(                        "4a05adc7-92ab-4185-8441-a5c893244375",                        [{"customdata":[[0,"game | team | games | he | players",1827],[1,"key | clipper | chip | encryption | keys",573],[2,"ites | cheek | yep | huh | ken",525],[3,"israel | israeli | jews | arab | jewish",469],[4,"ram | drive | sale | price | os",211],[5,"post | ted | you | frank | your",190],[6,"xterm | error | x11r5 | echo | server",187],[7,"amp | audio | condition | stereo | asking",180],[8,"card | drivers | diamond | driver | ati",175],[9,"car | cars | engine | ford